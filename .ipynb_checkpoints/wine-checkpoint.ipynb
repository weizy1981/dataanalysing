# %% [markdown]
# # 数据分析——葡萄酒品鉴
# 葡萄酒是以葡萄为原料酿造的一种果酒。其酒精度高于啤酒而低于白酒。营养丰富，保健作用明显。有人认为，葡萄酒是最健康最卫生的饮料之一。它能调整新陈代谢的性能，促进血液循环，防止胆固醇增加。还具有利尿、激发肝功能和防止衰老的功效。也是医治心脏病的辅助剂，可预防坏血病、贫血、脚气病、消化不良和眼角膜炎等疾病。常饮葡葡酒患心脏病率减少，血脂和血管硬化降低。目前，在中国也越来越多的人喜欢品尝葡萄酒，葡萄酒的品鉴，目前主要是靠品酒师来品鉴，人类能感觉的只有四种基本味感：甜、酸、咸、苦。四种基本呈味物质的敏感性不同，所以呈味物质在口腔中的反应速度也不同。舌尖对甜最敏感；接近舌尖的两侧对咸最敏感；舌的两侧对酸敏感；舌根对苦最敏感。那么，如何能够更精确的来判断葡萄酒的品级呢？通过鉴定葡萄酒的成人，结合品酒师的结论，能否实现以成分鉴定的方式，来给葡萄酒分级呢？在这里通过数据分析的手段，来看一下，葡萄酒成分与等级的关系。目前葡萄酒的分类主要有，以成品颜色来说，可分为红葡萄酒、白葡萄酒及粉红葡萄酒三类。这里收集了一部分红葡萄酒和白葡萄酒的数据，分析就在此基础上进行。

# %% [markdown]
# 首先导入使用的类库，然后读入数据，在这里的数据有红葡萄酒和白葡萄酒两个文件，分别读入到不同的DataFrame中。

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 读入红葡萄酒数据

# %%
red_wine = pd.read_csv('data/wine/winequality-red.csv', delimiter=';')
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# 读入白葡萄酒数据

# %%
white_wine = pd.read_csv('data/wine/winequality-white.csv', delimiter=';')
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %% [markdown]
# 数据读入后，检查一下数据中是否有缺失值。所谓缺失值就是数据收集整理过程中，该值不存在或者因为没有收集到，在数据文件中缺少的值。

# %%
red_wine.isnull().all()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
white_wine.isnull().all()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %% [markdown]
# 通过上述结果，可以看到数据中没有任何缺失值。接下来，结算一下数据项目之间的关联关系，并通过热力图来展示一下数据的关系。

# %%
red_corr = red_wine.corr()
red_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
from pyecharts import HeatMap
x_axis = y_axis = red_corr.index.tolist()
# print(y_axis)
values = red_corr.values
# values
data = [[i, j, values[i, j]] for i in range(len(x_axis)) for j in range(len(y_axis))]
heatmap = HeatMap()
heatmap.add(
    "相关性热力图",
    x_axis,
    y_axis,
    data,
    is_visualmap=True,
    visual_range=[-1, 1],
    visual_text_color="#000",
    visual_orient="horizontal",
    visual_pos="center",
    is_piecewise=True,
)
heatmap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0eb26e77f52c4a0995cf8c5579ccbbe6" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0eb26e77f52c4a0995cf8c5579ccbbe6 = echarts.init(document.getElementById('0eb26e77f52c4a0995cf8c5579ccbbe6'), 'light', {renderer: 'canvas'});
#
# var option_0eb26e77f52c4a0995cf8c5579ccbbe6 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 621818,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u76f8\u5173\u6027\u70ed\u529b\u56fe",
#             "data": [
#                 [
#                     0,
#                     0,
#                     1.0
#                 ],
#                 [
#                     0,
#                     1,
#                     -0.2561308947703819
#                 ],
#                 [
#                     0,
#                     2,
#                     0.6717034347641041
#                 ],
#                 [
#                     0,
#                     3,
#                     0.1147767244949209
#                 ],
#                 [
#                     0,
#                     4,
#                     0.093705186321305
#                 ],
#                 [
#                     0,
#                     5,
#                     -0.15379419286482485
#                 ],
#                 [
#                     0,
#                     6,
#                     -0.11318144304548039
#                 ],
#                 [
#                     0,
#                     7,
#                     0.6680472921189711
#                 ],
#                 [
#                     0,
#                     8,
#                     -0.6829781945685299
#                 ],
#                 [
#                     0,
#                     9,
#                     0.18300566393215348
#                 ],
#                 [
#                     0,
#                     10,
#                     -0.06166827062815111
#                 ],
#                 [
#                     0,
#                     11,
#                     0.1240516491132247
#                 ],
#                 [
#                     1,
#                     0,
#                     -0.2561308947703819
#                 ],
#                 [
#                     1,
#                     1,
#                     1.0
#                 ],
#                 [
#                     1,
#                     2,
#                     -0.5524956845595839
#                 ],
#                 [
#                     1,
#                     3,
#                     0.001917881962790698
#                 ],
#                 [
#                     1,
#                     4,
#                     0.06129777247646159
#                 ],
#                 [
#                     1,
#                     5,
#                     -0.010503827006591856
#                 ],
#                 [
#                     1,
#                     6,
#                     0.07647000482092836
#                 ],
#                 [
#                     1,
#                     7,
#                     0.02202623219521656
#                 ],
#                 [
#                     1,
#                     8,
#                     0.23493729440739436
#                 ],
#                 [
#                     1,
#                     9,
#                     -0.26098668528329055
#                 ],
#                 [
#                     1,
#                     10,
#                     -0.20228802715325686
#                 ],
#                 [
#                     1,
#                     11,
#                     -0.3905577802640094
#                 ],
#                 [
#                     2,
#                     0,
#                     0.6717034347641041
#                 ],
#                 [
#                     2,
#                     1,
#                     -0.5524956845595839
#                 ],
#                 [
#                     2,
#                     2,
#                     1.0
#                 ],
#                 [
#                     2,
#                     3,
#                     0.14357716157031483
#                 ],
#                 [
#                     2,
#                     4,
#                     0.20382291382904255
#                 ],
#                 [
#                     2,
#                     5,
#                     -0.06097812919230497
#                 ],
#                 [
#                     2,
#                     6,
#                     0.035533023931161666
#                 ],
#                 [
#                     2,
#                     7,
#                     0.3649471752112531
#                 ],
#                 [
#                     2,
#                     8,
#                     -0.5419041447395132
#                 ],
#                 [
#                     2,
#                     9,
#                     0.31277004385441737
#                 ],
#                 [
#                     2,
#                     10,
#                     0.10990324664156755
#                 ],
#                 [
#                     2,
#                     11,
#                     0.2263725143180432
#                 ],
#                 [
#                     3,
#                     0,
#                     0.1147767244949209
#                 ],
#                 [
#                     3,
#                     1,
#                     0.001917881962790698
#                 ],
#                 [
#                     3,
#                     2,
#                     0.14357716157031483
#                 ],
#                 [
#                     3,
#                     3,
#                     1.0
#                 ],
#                 [
#                     3,
#                     4,
#                     0.05560953520353216
#                 ],
#                 [
#                     3,
#                     5,
#                     0.18704899510428666
#                 ],
#                 [
#                     3,
#                     6,
#                     0.2030278816971015
#                 ],
#                 [
#                     3,
#                     7,
#                     0.3552833709833765
#                 ],
#                 [
#                     3,
#                     8,
#                     -0.08565242221887161
#                 ],
#                 [
#                     3,
#                     9,
#                     0.005527121339138363
#                 ],
#                 [
#                     3,
#                     10,
#                     0.04207543720973116
#                 ],
#                 [
#                     3,
#                     11,
#                     0.013731637340066346
#                 ],
#                 [
#                     4,
#                     0,
#                     0.093705186321305
#                 ],
#                 [
#                     4,
#                     1,
#                     0.06129777247646159
#                 ],
#                 [
#                     4,
#                     2,
#                     0.20382291382904255
#                 ],
#                 [
#                     4,
#                     3,

# %%
white_corr = white_wine.corr()
white_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.089021   0.023086            -0.049396
# volatile acidity            0.064286   0.070512            -0.097012
# citric acid                 0.094212   0.114364             0.094077
# residual sugar              1.000000   0.088685             0.299098
# chlorides                   0.088685   1.000000             0.101392
# free sulfur dioxide         0.299098   0.101392             1.000000
# total sulfur dioxide        0.401439   0.198910             0.615501
# density                     0.838966   0.257211             0.294210
# pH                         -0.194133  -0.090439            -0.000618
# sulphates                  -0.026664   0.016763             0.059217
# alcohol                    -0.450631  -0.360189            -0.250104
# quality                    -0.097577  -0.209934             0.008158
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.091070  0.265331 -0.425858  -0.017143
# volatile acidity                  0.089261  0.027114 -0.031915  -0.035728
# citric acid                       0.121131  0.149503 -0.163748   0.062331
# residual sugar                    0.401439  0.838966 -0.194133  -0.026664
# chlorides                         0.198910  0.257211 -0.090439   0.016763
# free sulfur dioxide               0.615501  0.294210 -0.000618   0.059217
# total sulfur dioxide              1.000000  0.529881  0.002321   0.134562
# density                           0.529881  1.000000 -0.093591   0.074493
# pH                                0.002321 -0.093591  1.000000   0.155951
# sulphates                         0.134562  0.074493  0.155951   1.000000
# alcohol                          -0.448892 -0.780138  0.121432  -0.017433
# quality                          -0.174737 -0.307123  0.099427   0.053678
#
#                        alcohol   quality
# fixed acidity        -0.120881 -0.113663
# volatile acidity      0.067718 -0.194723
# citric acid          -0.075729 -0.009209
# residual sugar       -0.450631 -0.097577
# chlorides            -0.360189 -0.209934
# free sulfur dioxide  -0.250104  0.008158
# total sulfur dioxide -0.448892 -0.174737
# density              -0.780138 -0.307123
# pH                    0.121432  0.099427
# sulphates            -0.017433  0.053678
# alcohol               1.000000  0.435575
# quality               0.435575  1.000000

# %%
x_axis = y_axis = red_corr.index.tolist()
# print(y_axis)
values = red_corr.values
# values
data = [[i, j, values[i, j]] for i in range(len(x_axis)) for j in range(len(y_axis))]
heatmap = HeatMap()
heatmap.add(
    "相关性热力图",
    x_axis,
    y_axis,
    data,
    is_visualmap=True,
    visual_range=[-1, 1],
    visual_text_color="#000",
    visual_orient="horizontal",
    visual_pos="center",
    is_piecewise=True,
)
heatmap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="33a3473afdef43778baaf6d9cf75cd8e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_33a3473afdef43778baaf6d9cf75cd8e = echarts.init(document.getElementById('33a3473afdef43778baaf6d9cf75cd8e'), 'light', {renderer: 'canvas'});
#
# var option_33a3473afdef43778baaf6d9cf75cd8e = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5877526,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u76f8\u5173\u6027\u70ed\u529b\u56fe",
#             "data": [
#                 [
#                     0,
#                     0,
#                     1.0
#                 ],
#                 [
#                     0,
#                     1,
#                     -0.2561308947703819
#                 ],
#                 [
#                     0,
#                     2,
#                     0.6717034347641041
#                 ],
#                 [
#                     0,
#                     3,
#                     0.1147767244949209
#                 ],
#                 [
#                     0,
#                     4,
#                     0.093705186321305
#                 ],
#                 [
#                     0,
#                     5,
#                     -0.15379419286482485
#                 ],
#                 [
#                     0,
#                     6,
#                     -0.11318144304548039
#                 ],
#                 [
#                     0,
#                     7,
#                     0.6680472921189711
#                 ],
#                 [
#                     0,
#                     8,
#                     -0.6829781945685299
#                 ],
#                 [
#                     0,
#                     9,
#                     0.18300566393215348
#                 ],
#                 [
#                     0,
#                     10,
#                     -0.06166827062815111
#                 ],
#                 [
#                     0,
#                     11,
#                     0.1240516491132247
#                 ],
#                 [
#                     1,
#                     0,
#                     -0.2561308947703819
#                 ],
#                 [
#                     1,
#                     1,
#                     1.0
#                 ],
#                 [
#                     1,
#                     2,
#                     -0.5524956845595839
#                 ],
#                 [
#                     1,
#                     3,
#                     0.001917881962790698
#                 ],
#                 [
#                     1,
#                     4,
#                     0.06129777247646159
#                 ],
#                 [
#                     1,
#                     5,
#                     -0.010503827006591856
#                 ],
#                 [
#                     1,
#                     6,
#                     0.07647000482092836
#                 ],
#                 [
#                     1,
#                     7,
#                     0.02202623219521656
#                 ],
#                 [
#                     1,
#                     8,
#                     0.23493729440739436
#                 ],
#                 [
#                     1,
#                     9,
#                     -0.26098668528329055
#                 ],
#                 [
#                     1,
#                     10,
#                     -0.20228802715325686
#                 ],
#                 [
#                     1,
#                     11,
#                     -0.3905577802640094
#                 ],
#                 [
#                     2,
#                     0,
#                     0.6717034347641041
#                 ],
#                 [
#                     2,
#                     1,
#                     -0.5524956845595839
#                 ],
#                 [
#                     2,
#                     2,
#                     1.0
#                 ],
#                 [
#                     2,
#                     3,
#                     0.14357716157031483
#                 ],
#                 [
#                     2,
#                     4,
#                     0.20382291382904255
#                 ],
#                 [
#                     2,
#                     5,
#                     -0.06097812919230497
#                 ],
#                 [
#                     2,
#                     6,
#                     0.035533023931161666
#                 ],
#                 [
#                     2,
#                     7,
#                     0.3649471752112531
#                 ],
#                 [
#                     2,
#                     8,
#                     -0.5419041447395132
#                 ],
#                 [
#                     2,
#                     9,
#                     0.31277004385441737
#                 ],
#                 [
#                     2,
#                     10,
#                     0.10990324664156755
#                 ],
#                 [
#                     2,
#                     11,
#                     0.2263725143180432
#                 ],
#                 [
#                     3,
#                     0,
#                     0.1147767244949209
#                 ],
#                 [
#                     3,
#                     1,
#                     0.001917881962790698
#                 ],
#                 [
#                     3,
#                     2,
#                     0.14357716157031483
#                 ],
#                 [
#                     3,
#                     3,
#                     1.0
#                 ],
#                 [
#                     3,
#                     4,
#                     0.05560953520353216
#                 ],
#                 [
#                     3,
#                     5,
#                     0.18704899510428666
#                 ],
#                 [
#                     3,
#                     6,
#                     0.2030278816971015
#                 ],
#                 [
#                     3,
#                     7,
#                     0.3552833709833765
#                 ],
#                 [
#                     3,
#                     8,
#                     -0.08565242221887161
#                 ],
#                 [
#                     3,
#                     9,
#                     0.005527121339138363
#                 ],
#                 [
#                     3,
#                     10,
#                     0.04207543720973116
#                 ],
#                 [
#                     3,
#                     11,
#                     0.013731637340066346
#                 ],
#                 [
#                     4,
#                     0,
#                     0.093705186321305
#                 ],
#                 [
#                     4,
#                     1,
#                     0.06129777247646159
#                 ],
#                 [
#                     4,
#                     2,
#                     0.20382291382904255
#                 ],
#                 [
#                     4,
#                     3,

# %% [markdown]
# 接下来通过关系图，再次确认哪个数据属性对酒的品质影响比加大。

# %%
from pyecharts import Graph
data = red_corr
#print(data)
nodes = []
for name in data.index.values:
    nodes.append({'name': name, 'symbolSize': data.at[name, 'quality'] * 50})

links = []
for i in nodes:
    for j in nodes:
        links.append({"source": i.get('name'), "target": j.get('name'), 
                      "value": data.at[i.get('name'), j.get('name')] * 50})
graph = Graph("红葡萄酒关系图-力引导布局示例")
graph.add("", nodes, links, graph_edge_length=250, is_label_show=True,)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="15b24c3ad5e046e9a28dbbc2038145cb" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_15b24c3ad5e046e9a28dbbc2038145cb = echarts.init(document.getElementById('15b24c3ad5e046e9a28dbbc2038145cb'), 'light', {renderer: 'canvas'});
#
# var option_15b24c3ad5e046e9a28dbbc2038145cb = {
#     "title": [
#         {
#             "text": "\u7ea2\u8461\u8404\u9152\u5173\u7cfb\u56fe-\u529b\u5f15\u5bfc\u5e03\u5c40\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7403160,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbol": "circle",
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 250,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#aaa"
#                 }
#             },
#             "roam": true,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "fixed acidity",
#                     "symbolSize": 6.202582455661235
#                 },
#                 {
#                     "name": "volatile acidity",
#                     "symbolSize": -19.52788901320047
#                 },
#                 {
#                     "name": "citric acid",
#                     "symbolSize": 11.31862571590216
#                 },
#                 {
#                     "name": "residual sugar",
#                     "symbolSize": 0.6865818670033174
#                 },
#                 {
#                     "name": "chlorides",
#                     "symbolSize": -6.445327996502656
#                 },
#                 {
#                     "name": "free sulfur dioxide",
#                     "symbolSize": -2.5328028622138214
#                 },
#                 {
#                     "name": "total sulfur dioxide",
#                     "symbolSize": -9.255014446326921
#                 },
#                 {
#                     "name": "density",
#                     "symbolSize": -8.745961389167503
#                 },
#                 {
#                     "name": "pH",
#                     "symbolSize": -2.8865695602691153
#                 },
#                 {
#                     "name": "sulphates",
#                     "symbolSize": 12.569853953463102
#                 },
#                 {
#                     "name": "alcohol",
#                     "symbolSize": 23.808316200057078
#                 },
#                 {
#                     "name": "quality",
#                     "symbolSize": 50.0
#                 }
#             ],
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "fixed acidity",
#                     "target": "fixed acidity",
#                     "value": 50.0
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "volatile acidity",
#                     "value": -12.806544738519095
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "citric acid",
#                     "value": 33.585171738205204
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "residual sugar",
#                     "value": 5.738836224746045
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "chlorides",
#                     "value": 4.685259316065251
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "free sulfur dioxide",
#                     "value": -7.689709643241242
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "total sulfur dioxide",
#                     "value": -5.659072152274019
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "density",
#                     "value": 33.402364605948556
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "pH",
#                     "value": -34.148909728426496
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "sulphates",
#                     "value": 9.150283196607674
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "alcohol",
#                     "value": -3.0834135314075555
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "quality",
#                     "value": 6.202582455661235
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "fixed acidity",
#                     "value": -12.806544738519095
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "volatile acidity",
#                     "value": 50.0
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "citric acid",
#                     "value": -27.624784227979195
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "residual sugar",
#                     "value": 0.09589409813953491
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "chlorides",
#                     "value": 3.0648886238230797
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "free sulfur dioxide",
#                     "value": -0.5251913503295927
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "total sulfur dioxide",
#                     "value": 3.823500241046418
#                 },
#                 {
#                     "source": "volatile acidity",

# %%
data = white_corr
#print(data)
nodes = []
for name in data.index.values:
    nodes.append({'name': name, 'symbolSize': data.at[name, 'quality'] * 50})

links = []
for i in nodes:
    for j in nodes:
        links.append({"source": i.get('name'), "target": j.get('name'), 
                      "value": data.at[i.get('name'), j.get('name')] * 50})
graph = Graph("白葡萄酒关系图-力引导布局示例")
graph.add("", nodes, links, graph_edge_length=250, is_label_show=True,)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="10b8121fa26b4d628655fff0a5b882f9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_10b8121fa26b4d628655fff0a5b882f9 = echarts.init(document.getElementById('10b8121fa26b4d628655fff0a5b882f9'), 'light', {renderer: 'canvas'});
#
# var option_10b8121fa26b4d628655fff0a5b882f9 = {
#     "title": [
#         {
#             "text": "\u767d\u8461\u8404\u9152\u5173\u7cfb\u56fe-\u529b\u5f15\u5bfc\u5e03\u5c40\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8776845,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbol": "circle",
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 250,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#aaa"
#                 }
#             },
#             "roam": true,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "fixed acidity",
#                     "symbolSize": -5.683141535650753
#                 },
#                 {
#                     "name": "volatile acidity",
#                     "symbolSize": -9.736148446056678
#                 },
#                 {
#                     "name": "citric acid",
#                     "symbolSize": -0.4604545441987647
#                 },
#                 {
#                     "name": "residual sugar",
#                     "symbolSize": -4.878841444734601
#                 },
#                 {
#                     "name": "chlorides",
#                     "symbolSize": -10.496720547337802
#                 },
#                 {
#                     "name": "free sulfur dioxide",
#                     "symbolSize": 0.40790335617179746
#                 },
#                 {
#                     "name": "total sulfur dioxide",
#                     "symbolSize": -8.73686087985302
#                 },
#                 {
#                     "name": "density",
#                     "symbolSize": -15.356165636736275
#                 },
#                 {
#                     "name": "pH",
#                     "symbolSize": 4.971362286833128
#                 },
#                 {
#                     "name": "sulphates",
#                     "symbolSize": 2.683893856639593
#                 },
#                 {
#                     "name": "alcohol",
#                     "symbolSize": 21.77873577306844
#                 },
#                 {
#                     "name": "quality",
#                     "symbolSize": 50.0
#                 }
#             ],
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "fixed acidity",
#                     "target": "fixed acidity",
#                     "value": 50.0
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "volatile acidity",
#                     "value": -1.134864507332361
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "citric acid",
#                     "value": 14.459034884683547
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "residual sugar",
#                     "value": 4.451035068108555
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "chlorides",
#                     "value": 1.1542821828173773
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "free sulfur dioxide",
#                     "value": -2.4697929540586476
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "total sulfur dioxide",
#                     "value": 4.5534878079320205
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "density",
#                     "value": 13.26655069195923
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "pH",
#                     "value": -21.292914549568884
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "sulphates",
#                     "value": -0.8571492510568657
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "alcohol",
#                     "value": -6.044056159726621
#                 },
#                 {
#                     "source": "fixed acidity",
#                     "target": "quality",
#                     "value": -5.683141535650753
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "fixed acidity",
#                     "value": -1.134864507332361
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "volatile acidity",
#                     "value": 50.0
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "citric acid",
#                     "value": -7.4735905324288145
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "residual sugar",
#                     "value": 3.214303004549813
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "chlorides",
#                     "value": 3.52557857396927
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "free sulfur dioxide",
#                     "value": -4.850596963898074
#                 },
#                 {
#                     "source": "volatile acidity",
#                     "target": "total sulfur dioxide",
#                     "value": 4.463025177588958
#                 },
#                 {
#                     "source": "volatile acidity",

# %% [markdown]
# 接下来查看一下，对葡萄酒品级影响的相关性的数据，如下：

# %%
corr_map = pd.concat([red_corr['quality'], white_corr['quality']], axis=1)
corr_map.columns = ['red_wine_quality', 'white_wine_quality']
corr_map.drop(index=['quality'], inplace=True)
corr_map
# Out:
#                       red_wine_quality  white_wine_quality
# fixed acidity                 0.124052           -0.113663
# volatile acidity             -0.390558           -0.194723
# citric acid                   0.226373           -0.009209
# residual sugar                0.013732           -0.097577
# chlorides                    -0.128907           -0.209934
# free sulfur dioxide          -0.050656            0.008158
# total sulfur dioxide         -0.185100           -0.174737
# density                      -0.174919           -0.307123
# pH                           -0.057731            0.099427
# sulphates                     0.251397            0.053678
# alcohol                       0.476166            0.435575

# %%
from pyecharts import Bar
bar = Bar('萄酒品质相关性比较')
labels = corr_map.index.tolist()
red_values = [i for i in corr_map['red_wine_quality'].values]
white_values = [i for i in corr_map['white_wine_quality'].values]
bar.add('red wine', labels, red_values, 
        mark_line_raw=[{'name': '标线', 'yAxis': '0.2'}, {'name': '标线', 'yAxis': '-0.2'}])
bar.add('white wine', labels, white_values,
        mark_line_raw=[{'name': '标线', 'yAxis': '0.2'}, {'name': '标线', 'yAxis': '-0.2'}])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2cf21dcb5d2244fdaa1b87f9179eff12" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2cf21dcb5d2244fdaa1b87f9179eff12 = echarts.init(document.getElementById('2cf21dcb5d2244fdaa1b87f9179eff12'), 'light', {renderer: 'canvas'});
#
# var option_2cf21dcb5d2244fdaa1b87f9179eff12 = {
#     "title": [
#         {
#             "text": "\u8404\u9152\u54c1\u8d28\u76f8\u5173\u6027\u6bd4\u8f83",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2136217,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "red wine",
#             "data": [
#                 0.1240516491132247,
#                 -0.3905577802640094,
#                 0.2263725143180432,
#                 0.013731637340066346,
#                 -0.12890655993005312,
#                 -0.05065605724427643,
#                 -0.18510028892653843,
#                 -0.17491922778335006,
#                 -0.0577313912053823,
#                 0.25139707906926206,
#                 0.47616632400114156
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "name": "\u6807\u7ebf",
#                         "yAxis": "0.2"
#                     },
#                     {
#                         "name": "\u6807\u7ebf",
#                         "yAxis": "-0.2"
#                     }
#                 ]
#             },
#             "seriesId": 2136217
#         },
#         {
#             "type": "bar",
#             "name": "white wine",
#             "data": [
#                 -0.11366283071301507,
#                 -0.19472296892113355,
#                 -0.009209090883975294,
#                 -0.09757682889469202,
#                 -0.20993441094675602,
#                 0.008158067123435949,
#                 -0.17473721759706043,
#                 -0.3071233127347255,
#                 0.09942724573666256,
#                 0.05367787713279186,
#                 0.4355747154613688
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "name": "\u6807\u7ebf",
#                         "yAxis": "0.2"
#                     },
#                     {
#                         "name": "\u6807\u7ebf",
#                         "yAxis": "-0.2"
#                     }
#                 ]
#             },
#             "seriesId": 2136217
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "red wine",
#                 "white wine"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "fixed acidity",
#                 "volatile acidity",
#                 "citric acid",
#                 "residual sugar",
#                 "chlorides",
#                 "free sulfur dioxide",
#                 "total sulfur dioxide",
#                 "density",
#                 "pH",
#                 "sulphates",
#                 "alcohol"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_2cf21dcb5d2244fdaa1b87f9179eff12.setOption(option_2cf21dcb5d2244fdaa1b87f9179eff12);
#
#     });
# </script>

# %% [markdown]
# 通过这个图的对比看一看到，在红葡萄酒中，在-0.2 与0.2之外的项目有：volatile acidity, citric acid, sulphates, alcohol；白葡萄酒是：volatile acidity, chlorides, density, alcohol。其中，alcohol对红葡萄酒和白葡萄酒来说，都对品质产生比较大的影响。接下里，就看一下酒精度对葡萄酒品质的影响是什么样子的，散点图很好的描述了x, y之间的变化关系。

# %%
from pyecharts import Scatter
scatter = Scatter('精度对葡萄酒品质的影响')
red_wine_alcohol = [i for i in red_wine['alcohol']]
red_wine_quality = [i for i in red_wine['quality']]
scatter.add('红葡萄酒', red_wine_alcohol, red_wine_quality)

white_wine_alcohol = [i for i in white_wine['alcohol']]
white_wine_quality = [i for i in white_wine['quality']]
scatter.add('白葡萄酒', white_wine_alcohol, white_wine_quality)
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8311cc35fb0c450eb0a766a29ddc3cfc" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8311cc35fb0c450eb0a766a29ddc3cfc = echarts.init(document.getElementById('8311cc35fb0c450eb0a766a29ddc3cfc'), 'light', {renderer: 'canvas'});
#
# var option_8311cc35fb0c450eb0a766a29ddc3cfc = {
#     "title": [
#         {
#             "text": "\u7cbe\u5ea6\u5bf9\u8461\u8404\u9152\u54c1\u8d28\u7684\u5f71\u54cd",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2835859,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u7ea2\u8461\u8404\u9152",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     9.4,
#                     5
#                 ],
#                 [
#                     9.8,
#                     5
#                 ],
#                 [
#                     9.8,
#                     5
#                 ],
#                 [
#                     9.8,
#                     6
#                 ],
#                 [
#                     9.4,
#                     5
#                 ],
#                 [
#                     9.4,
#                     5
#                 ],
#                 [
#                     9.4,
#                     5
#                 ],
#                 [
#                     10.0,
#                     7
#                 ],
#                 [
#                     9.5,
#                     7
#                 ],
#                 [
#                     10.5,
#                     5
#                 ],
#                 [
#                     9.2,
#                     5
#                 ],
#                 [
#                     10.5,
#                     5
#                 ],
#                 [
#                     9.9,
#                     5
#                 ],
#                 [
#                     9.1,
#                     5
#                 ],
#                 [
#                     9.2,
#                     5
#                 ],
#                 [
#                     9.2,
#                     5
#                 ],
#                 [
#                     10.5,
#                     7
#                 ],
#                 [
#                     9.3,
#                     5
#                 ],
#                 [
#                     9.0,
#                     4
#                 ],
#                 [
#                     9.2,
#                     6
#                 ],
#                 [
#                     9.4,
#                     6
#                 ],
#                 [
#                     9.7,
#                     5
#                 ],
#                 [
#                     9.5,
#                     5
#                 ],
#                 [
#                     9.4,
#                     5
#                 ],
#                 [
#                     9.7,
#                     6
#                 ],
#                 [
#                     9.3,
#                     5
#                 ],
#                 [
#                     9.5,
#                     5
#                 ],
#                 [
#                     9.5,
#                     5
#                 ],
#                 [
#                     9.4,
#                     5
#                 ],
#                 [
#                     9.8,
#                     6
#                 ],
#                 [
#                     10.1,
#                     5
#                 ],
#                 [
#                     10.6,
#                     6
#                 ],
#                 [
#                     9.8,
#                     5
#                 ],
#                 [
#                     9.4,
#                     6
#                 ],
#                 [
#                     9.2,
#                     5
#                 ],
#                 [
#                     9.6,
#                     6
#                 ],
#                 [
#                     10.8,
#                     6
#                 ],
#                 [
#                     9.7,
#                     7
#                 ],
#                 [
#                     9.8,
#                     4
#                 ],
#                 [
#                     10.5,
#                     5
#                 ],
#                 [
#                     10.5,
#                     5
#                 ],
#                 [
#                     9.3,
#                     4
#                 ],
#                 [
#                     10.5,
#                     6
#                 ],
#                 [
#                     10.3,
#                     5
#                 ],
#                 [
#                     9.5,
#                     5
#                 ],
#                 [
#                     13.1,
#                     4
#                 ],
#                 [
#                     9.2,
#                     5
#                 ],
#                 [
#                     9.5,
#                     5
#                 ],
#                 [
#                     9.2,
#                     5
#                 ],
#                 [
#                     9.2,
#                     5
#                 ],
#                 [
#                     9.2,
#                     5
#                 ],
#                 [
#                     9.4,
#                     6
#                 ],
#                 [
#                     9.4,
#                     6
#                 ],
#                 [
#                     9.4,
#                     5
#                 ],
#                 [
#                     10.2,
#                     6
#                 ],
#                 [
#                     9.5,
#                     5
#                 ],
#                 [
#                     9.6,
#                     5
#                 ],
#                 [
#                     9.4,
#                     5
#                 ],
#                 [
#                     10.0,
#                     5
#                 ],
#                 [
#                     9.4,
#                     6
#                 ],
#                 [
#                     9.2,
#                     5
#                 ],
#                 [
#                     9.3,
#                     5
#                 ],
#                 [
#                     9.5,
#                     7
#                 ],
#                 [
#                     9.8,
#                     5
#                 ],
#                 [
#                     10.9,
#                     5
#                 ],
#                 [
#                     10.9,
#                     5
#                 ],
#                 [
#                     9.6,
#                     5
#                 ],
#                 [
#                     10.7,
#                     5
#                 ],
#                 [
#                     10.7,
#                     5
#                 ],
#                 [
#                     10.5,
#                     6
#                 ],
#                 [
#                     9.5,
#                     6
#                 ],
#                 [
#                     9.5,
#                     5
#                 ],
#                 [
#                     9.5,
#                     5
#                 ],

# %% [markdown]
# 因为数据量太大，不能很直观的看出来葡萄酒品质随酒精度的变化情况，要考虑一下其他的方式来进行一步分析。虽然，不是变化规律不是非常清新，但是也能发现，随着酒精度的增加，品质有所提高，在这里将数据安装品质等级分组，然后通过箱线图来看一下，在同一个品级下，数据的分布情况，并比较不同分品级的分布状况。

# %%
x_axis = ['3', '4', '5', '6', '7', '8', '9']
y1_axis = []
for level in x_axis:
    data = red_wine[red_wine['quality'] == int(level)]
    values = [i for i in data['alcohol']]
    y1_axis.append(values)
    
y2_axis = []
for level in x_axis:
    data = white_wine[white_wine['quality'] == int(level)]
    values = [i for i in data['alcohol']]
    y2_axis.append(values)

# %%
from pyecharts import Boxplot
boxplot = Boxplot('葡萄酒品质')
boxplot.add('红葡萄酒', x_axis, boxplot.prepare_data(y1_axis))
boxplot.add('白葡萄酒', x_axis, boxplot.prepare_data(y2_axis))
boxplot
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6739cee7143a42c2857a3048f2ed96cd" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6739cee7143a42c2857a3048f2ed96cd = echarts.init(document.getElementById('6739cee7143a42c2857a3048f2ed96cd'), 'light', {renderer: 'canvas'});
#
# var option_6739cee7143a42c2857a3048f2ed96cd = {
#     "title": [
#         {
#             "text": "\u8461\u8404\u9152\u54c1\u8d28",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 564876,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u7ea2\u8461\u8404\u9152",
#             "data": [
#                 [
#                     8.4,
#                     9.524999999999999,
#                     9.925,
#                     10.749999999999998,
#                     11.0
#                 ],
#                 [
#                     9.0,
#                     9.6,
#                     10.0,
#                     11.0,
#                     13.1
#                 ],
#                 [
#                     8.5,
#                     9.4,
#                     9.7,
#                     10.2,
#                     14.9
#                 ],
#                 [
#                     8.4,
#                     9.8,
#                     10.5,
#                     11.3,
#                     14.0
#                 ],
#                 [
#                     9.2,
#                     10.8,
#                     11.5,
#                     12.1,
#                     14.0
#                 ],
#                 [
#                     9.8,
#                     11.225000000000001,
#                     12.15,
#                     12.950000000000001,
#                     14.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 564876
#         },
#         {
#             "type": "boxplot",
#             "name": "\u767d\u8461\u8404\u9152",
#             "data": [
#                 [
#                     8.0,
#                     9.450000000000001,
#                     10.45,
#                     11.0,
#                     12.6
#                 ],
#                 [
#                     8.4,
#                     9.4,
#                     10.1,
#                     10.8,
#                     13.5
#                 ],
#                 [
#                     8.0,
#                     9.2,
#                     9.5,
#                     10.3,
#                     13.6
#                 ],
#                 [
#                     8.5,
#                     9.6,
#                     10.5,
#                     11.4,
#                     14.0
#                 ],
#                 [
#                     8.6,
#                     10.6,
#                     11.4,
#                     12.3,
#                     14.2
#                 ],
#                 [
#                     8.5,
#                     11.0,
#                     12.0,
#                     12.6,
#                     14.0
#                 ],
#                 [
#                     10.4,
#                     11.4,
#                     12.5,
#                     12.8,
#                     12.9
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 564876
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7ea2\u8461\u8404\u9152",
#                 "\u767d\u8461\u8404\u9152"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "3",
#                 "4",
#                 "5",
#                 "6",
#                 "7",
#                 "8",
#                 "9"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6

# %% [markdown]
# 通过上面的箱线图，结合之前的散点图，基本可以得出红酒的品质，随着酒精度的提高，有所增加。这对红葡萄酒和白葡萄酒都适用。然后，可以在分析一个负相关项目-挥发酸（volatile acidity）与葡萄酒品级的关系。这个留给读者自行验证。
